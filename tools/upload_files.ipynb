# %%
from aws import *
import json


def read_json(json_file):
    with open(json_file) as f:
        return json.load(f)


wd = '/Users/danielmsheehan/Dropbox/General_Assembly/Projects/project_5/data'
config = read_json('config.json')

for g in ['sp', 'rj']:
    local_file = f"{wd}/output/{g}_master.csv"
    s3_filename = f"{g}_master.csv"
    
    file_to_s3(
        s3_session_connect(
            aws_connect(config['access_key_id'], config['secret_access_key'])
        ),
        'general-assembly-project-5',
        local_file,
        s3_filename,
    )

    link = f'https://general-assembly-project-5.s3.amazonaws.com/{g}_master.csv'
    print('    aws url: {}'.format(link))
# Out:
# --------------------------------------------------------------------------
# KeyboardInterrupt                        Traceback (most recent call last)
# <ipython-input-35-42e48b20ac3e> in <module>
#      21         'general-assembly-project-5',
#      22         local_file,
# ---> 23         s3_filename,
#      24     )
#      25
#
# ~/general_assembly/github/projects/project_5/delta/tools/aws.py in file_to_s3(s3_session, bucket_name, file_to_upload, filename_on_s3)
#      22         Key=filename_on_s3,
#      23         Body=data,
# ---> 24         ACL='public-read',
#      25     )
#      26
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/boto3/resources/factory.py in do_action(self, *args, **kwargs)
#     518             # instance via ``self``.
#     519             def do_action(self, *args, **kwargs):
# --> 520                 response = action(self, *args, **kwargs)
#     521
#     522                 if hasattr(self, 'load'):
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/boto3/resources/action.py in __call__(self, parent, *args, **kwargs)
#      81                     operation_name, params)
#      82
# ---> 83         response = getattr(parent.meta.client, operation_name)(**params)
#      84
#      85         logger.debug('Response: %r', response)
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     274                     "%s() only accepts keyword arguments." % py_operation_name)
#     275             # The "self" in this scope is referring to the BaseClient.
# --> 276             return self._make_api_call(operation_name, kwargs)
#     277
#     278         _api_call.__name__ = str(py_operation_name)
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     571         else:
#     572             http, parsed_response = self._make_request(
# --> 573                 operation_model, request_dict, request_context)
#     574
#     575         self.meta.events.emit(
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/botocore/client.py in _make_request(self, operation_model, request_dict, request_context)
#     590     def _make_request(self, operation_model, request_dict, request_context):
#     591         try:
# --> 592             return self._endpoint.make_request(operation_model, request_dict)
#     593         except Exception as e:
#     594             self.meta.events.emit(
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/botocore/endpoint.py in make_request(self, operation_model, request_dict)
#     100         logger.debug("Making request for %s with params: %s",
#     101                      operation_model, request_dict)
# --> 102         return self._send_request(request_dict, operation_model)
#     103
#     104     def create_request(self, params, operation_model=None):
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/botocore/endpoint.py in _send_request(self, request_dict, operation_model)
#     133         context = request_dict['context']
#     134         success_response, exception = self._get_response(
# --> 135             request, operation_model, context)
#     136         while self._needs_retry(attempts, operation_model, request_dict,
#     137                                 success_response, exception):
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/botocore/endpoint.py in _get_response(self, request, operation_model, context)
#     165         # If no exception occurs then exception is None.
#     166         success_response, exception = self._do_get_response(
# --> 167             request, operation_model)
#     168         kwargs_to_emit = {
#     169             'response_dict': None,
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/botocore/endpoint.py in _do_get_response(self, request, operation_model)
#     198             http_response = first_non_none_response(responses)
#     199             if http_response is None:
# --> 200                 http_response = self._send(request)
#     201         except HTTPClientError as e:
#     202             return (None, e)
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/botocore/endpoint.py in _send(self, request)
#     242
#     243     def _send(self, request):
# --> 244         return self.http_session.send(request)
#     245
#     246
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/botocore/httpsession.py in send(self, request)
#     261                 preload_content=False,
#     262                 decode_content=False,
# --> 263                 chunked=self._chunked(request.headers),
#     264             )
#     265
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385             conn.request_chunked(method, url, **httplib_request_kw)
#     386         else:
# --> 387             conn.request(method, url, **httplib_request_kw)
#     388
#     389         # Reset the timeout for the recv() on the socket
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1250                 encode_chunked=False):
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#    1254     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/botocore/awsrequest.py in _send_request(self, method, url, body, headers, *args, **kwargs)
#      90             self.response_class = self._original_response_cls
#      91         rval = super(AWSConnection, self)._send_request(
# ---> 92             method, url, body, headers, *args, **kwargs)
#      93         self._expect_header_set = False
#      94         return rval
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1296             # default charset of iso-8859-1.
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
#    1299
#    1300     def getresponse(self):
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1245         else:
#    1246             raise CannotSendHeader()
# -> 1247         self._send_output(message_body, encode_chunked=encode_chunked)
#    1248
#    1249     def request(self, method, url, body=None, headers={}, *,
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/botocore/awsrequest.py in _send_output(self, message_body, *args, **kwargs)
#     124             # Wait for 1 second for the server to send a response.
#     125             if urllib3.util.wait_for_read(self.sock, 1):
# --> 126                 self._handle_expect_response(message_body)
#     127                 return
#     128             else:
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/botocore/awsrequest.py in _handle_expect_response(self, message_body)
#     167                 logger.debug("100 Continue response seen, "
#     168                              "now sending request body.")
# --> 169                 self._send_message_body(message_body)
#     170             elif len(parts) == 3 and parts[0].startswith(b'HTTP/'):
#     171                 # From the RFC:
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/botocore/awsrequest.py in _send_message_body(self, message_body)
#     194     def _send_message_body(self, message_body):
#     195         if message_body is not None:
# --> 196             self.send(message_body)
#     197
#     198     def send(self, str):
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/botocore/awsrequest.py in send(self, str)
#     201                          "Not sending data.")
#     202             return
# --> 203         return super(AWSConnection, self).send(str)
#     204
#     205     def _is_100_continue_status(self, maybe_status_line):
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/http/client.py in send(self, data)
#     982                 if encode:
#     983                     datablock = datablock.encode("iso-8859-1")
# --> 984                 self.sock.sendall(datablock)
#     985             return
#     986         try:
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/ssl.py in sendall(self, data, flags)
#    1032                 amount = len(byte_view)
#    1033                 while count < amount:
# -> 1034                     v = self.send(byte_view[count:])
#    1035                     count += v
#    1036         else:
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/ssl.py in send(self, data, flags)
#    1001                     "non-zero flags not allowed in calls to send() on %s" %
#    1002                     self.__class__)
# -> 1003             return self._sslobj.write(data)
#    1004         else:
#    1005             return super().send(data, flags)
#
# KeyboardInterrupt:

# %%
import pandas as pd

# df = pd.read_csv('https://general-assembly-project-5.s3.amazonaws.com/sp_master.csv')



wd = '/Users/danielmsheehan/Dropbox/General_Assembly/Projects/project_5/data'
config = read_json('config.json')

df = pd.read_csv(f"{wd}/output/sp_master.csv")

df.head()
# Out:
#         cd_geocodi nm_subdist nm_distrit nm_municip nm_micro  \
# 0  350570810000023                ALDEIA    BARUERI   OSASCO
# 1  350570810000023                ALDEIA    BARUERI   OSASCO
# 2  350570810000023                ALDEIA    BARUERI   OSASCO
# 3  350570810000023                ALDEIA    BARUERI   OSASCO
# 4  350570810000023                ALDEIA    BARUERI   OSASCO
#
#                       nm_meso   id1  geog_orig_area  favela_present  \
# 0  METROPOLITANA DE STO PAULO  4151   225738.343447             NaN
# 1  METROPOLITANA DE STO PAULO  4151   225738.343447             NaN
# 2  METROPOLITANA DE STO PAULO  4151   225738.343447             NaN
# 3  METROPOLITANA DE STO PAULO  4151   225738.343447             NaN
# 4  METROPOLITANA DE STO PAULO  4151   225738.343447             NaN
#
#    favela_area_squaremeters  ...  brazil_store_count_listings  \
# 0                       NaN  ...                          NaN
# 1                       NaN  ...                          NaN
# 2                       NaN  ...                          NaN
# 3                       NaN  ...                          NaN
# 4                       NaN  ...                          NaN
#
#    brazil_store_near_fid  brazil_store_near_dist  brazil_store_near_angle  \
# 0                    NaN                     NaN                      NaN
# 1                    NaN                     NaN                      NaN
# 2                    NaN                     NaN                      NaN
# 3                    NaN                     NaN                      NaN
# 4                    NaN                     NaN                      NaN
#
#    brazil_store_price  brazil_ph_count_listings  brazil_ph_near_fid  \
# 0                 NaN                       NaN                 NaN
# 1                 NaN                       NaN                 NaN
# 2                 NaN                       NaN                 NaN
# 3                 NaN                       NaN                 NaN
# 4                 NaN                       NaN                 NaN
#
#    brazil_ph_near_dist  brazil_ph_near_angle  brazil_ph_price
# 0                  NaN                   NaN              NaN
# 1                  NaN                   NaN              NaN
# 2                  NaN                   NaN              NaN
# 3                  NaN                   NaN              NaN
# 4                  NaN                   NaN              NaN
#
# [5 rows x 35 columns]

# %%
for i in df.columns:
    print(i)
# Out:
# cd_geocodi
# nm_subdist
# nm_distrit
# nm_municip
# nm_micro
# nm_meso
# id1
# geog_orig_area
# favela_present
# favela_area_squaremeters
# sao_paulo_apartment_count_listings
# sao_paulo_apartment_near_fid
# sao_paulo_apartment_near_dist
# sao_paulo_apartment_near_angle
# sao_paulo_apartment_price
# brazil_apartment_count_listings
# brazil_apartment_near_fid
# brazil_apartment_near_dist
# brazil_apartment_near_angle
# brazil_apartment_price
# brazil_house_count_listings
# brazil_house_near_fid
# brazil_house_near_dist
# brazil_house_near_angle
# brazil_house_price
# brazil_store_count_listings
# brazil_store_near_fid
# brazil_store_near_dist
# brazil_store_near_angle
# brazil_store_price
# brazil_ph_count_listings
# brazil_ph_near_fid
# brazil_ph_near_dist
# brazil_ph_near_angle
# brazil_ph_price

# %%
import missingno as msno
msno.matrix(df)
# Out:
# --------------------------------------------------------------------------
# KeyboardInterrupt                        Traceback (most recent call last)
# <ipython-input-33-f159fe30545d> in <module>
#       1 import missingno as msno
# ----> 2 msno.matrix(df)
#
# ~/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/missingno/missingno.py in matrix(df, filter, n, p, sort, figsize, width_ratios, color, fontsize, labels, sparkline, inline, freq, ax)
#      44
#      45     g[z < 0.5] = [1, 1, 1]
# ---> 46     g[z > 0.5] = color
#      47
#      48     # Set up the matplotlib grid layout. A unary subplot if no sparkline, a left-right splot if yes sparkline.
#
# KeyboardInterrupt:

# %%
df.shape
# Out:
# (2891330, 35)

# %%
df.isnull().sum()
# Out:
# cd_geocodi                                  0
# nm_subdist                                  0
# nm_distrit                                  0
# nm_municip                                  0
# nm_micro                                    0
# nm_meso                                     0
# id1                                         0
# geog_orig_area                              0
# favela_present                        2874871
# favela_area_squaremeters              2874871
# sao_paulo_apartment_count_listings    2882049
# sao_paulo_apartment_near_fid           350332
# sao_paulo_apartment_near_dist          350332
# sao_paulo_apartment_near_angle         350332
# sao_paulo_apartment_price              350332
# brazil_apartment_count_listings       2801094
# brazil_apartment_near_fid              840209
# brazil_apartment_near_dist             840209
# brazil_apartment_near_angle            840209
# brazil_apartment_price                 840209
# brazil_house_count_listings           2829596
# brazil_house_near_fid                  319712
# brazil_house_near_dist                 319712
# brazil_house_near_angle                319712
# brazil_house_price                     319712
# brazil_store_count_listings           2830168
# brazil_store_near_fid                  219831
# brazil_store_near_dist                 219831
# brazil_store_near_angle                219831
# brazil_store_price                     219831
# brazil_ph_count_listings              2891078
# brazil_ph_near_fid                     481695
# brazil_ph_near_dist                    481695
# brazil_ph_near_angle                   481695
# brazil_ph_price                        481695
# dtype: int64
